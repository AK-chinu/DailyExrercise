# %%
import pandas as pd

# %%
df=pd.read_csv('services.csv')

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df.describe()
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %%
df[['alternate_name','audience','keywords','website']]
# Out:
#            alternate_name                                           audience  \
# 0                     NaN  Older adults age 55 or over, ethnic minorities...
# 1                     NaN       Residents of San Mateo County age 55 or over
# 2                     NaN  Older adults age 55 or over who can benefit fr...
# 3                     NaN  Parents, children, families with problems of c...
# 4                     NaN  Low-income working families with children tran...
# 5                     NaN                                            Any age
# 6                     NaN  Older adults who have memory or sensory loss, ...
# 7                     NaN  Senior citizens age 60 or over, disabled indiv...
# 8                     NaN     Ethnic minorities, especially Spanish speaking
# 9                     NaN                                                NaN
# 10                    NaN                                                NaN
# ...

# %%
df.dtypes=='object'
# Out:
# id                         False
# location_id                False
# program_id                 False
# accepted_payments           True
# alternate_name              True
# application_process         True
# audience                    True
# description                 True
# eligibility                 True
# email                       True
# fees                        True
# funding_sources             True
# interpretation_services     True
# keywords                    True
# languages                   True
# name                        True
# required_documents          True
# service_areas               True
# status                      True
# wait_time                   True
# website                     True
# taxonomy_ids                True
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['accepted_payments', 'alternate_name', 'application_process',
#        'audience', 'description', 'eligibility', 'email', 'fees',
#        'funding_sources', 'interpretation_services', 'keywords', 'languages',
#        'name', 'required_documents', 'service_areas', 'status', 'wait_time',
#        'website', 'taxonomy_ids'],
#       dtype='object')

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#                accepted_payments         alternate_name  \
# count                          1                      1
# unique                         1                      1
# top     Cash, Check, Credit Card  Fotos para pasaportes
# freq                           1                      1
#
#                       application_process  \
# count                                  23
# unique                                 20
# top     Walk in or apply by phone or mail
# freq                                    2
#
#                                                  audience  \
# count                                                  14
# unique                                                 14
# top     Older adults age 55 or over, ethnic minorities...
# freq                                                    1
#
#                                               description  \
# count                                                  23
# ...
